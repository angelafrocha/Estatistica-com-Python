# %% [markdown]
# <a href="https://colab.research.google.com/github/angelafrocha/Estatistica-com-Python/blob/main/Teste_Wilcoxon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Um novo tratamento para acabar com o hábito de fumar está sendo empregado em um grupo de **35 pacientes** voluntários. De cada paciente testado foram obtidas as informações de quantidades de cigarros consumidos por dia antes e depois do término do tratamento. Assumindo um **nível de confiança de 95%** é possível concluir que, depois da aplicação do novo tratamento, houve uma mudança no hábito de fumar do grupo de pacientes testado?

# %% [markdown]
# **Teste Wilcoxon**
# Comparação de duas populações - amostras dependentes
# Empregado quando se deseja comparar duas amostras relacionadas, amostras emparelhadas. Pode ser aplicado quando se deseja testar a diferença de duas condições, isto é, quando um mesmo elemento é submetido a duas medidas.

# %%
import pandas as pd
import numpy as np
from scipy.stats import wilcoxon

# %%
fumo = {
    'Antes': [39, 25, 24, 50, 13, 52, 21, 29, 10, 22, 50, 15, 36, 39, 52, 48, 24, 15, 40, 41, 17, 12, 21, 49, 14, 55, 46, 22, 28, 23, 37, 17, 31, 49, 49],
    'Depois': [16, 8, 12, 0, 14, 16, 13, 12, 19, 17, 17, 2, 15, 10, 20, 13, 0, 4, 16, 18, 16, 16, 9, 9, 18, 4, 17, 0, 11, 14, 0, 19, 2, 9, 6]
}
significancia = 0.05
confianca = 1 - significancia
n = 35

# %%
fumo = pd.DataFrame(fumo)
fumo.head()
# Out:
#    Antes  Depois
# 0     39      16
# 1     25       8
# 2     24      12
# 3     50       0
# 4     13      14

# %%
antes = fumo['Antes']
depois = fumo['Depois']

# %%
# Teste de Wilcoxon
stat, p_valor = wilcoxon(antes, depois)

print(f"Estatística de teste: {stat:.4f}")
print(f"P-valor: {p_valor:.4f}")

# Conclusão
if p_valor <= significancia:
    print("Com 95% de confiança, podemos rejeitar a hipótese nula e concluir que houve uma mudança significativa no hábito de fumar após o tratamento.")
else:
    print("Com 95% de confiança, não temos evidências suficientes para rejeitar a hipótese nula. Não podemos afirmar que houve uma mudança significativa no hábito de fumar após o tratamento.")
# Out:
# Estatística de teste: 22.0000
# P-valor: 0.0000
# Com 95% de confiança, podemos rejeitar a hipótese nula e concluir que houve uma mudança significativa no hábito de fumar após o tratamento.
